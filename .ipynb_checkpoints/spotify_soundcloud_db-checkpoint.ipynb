# %%
#import dependencies 
#import dependencies to read the files 
import os 
import csv 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import json
import requests
from pprint import pprint
import scipy.stats as st
import pymongo

# %% [markdown]
# # Importing Spotify Top 200 data

# %%
# File to Load
file_to_load = "Data/charts.csv"

# Read Purchasing File and store into Pandas data frame
spotify_charts = pd.read_csv(file_to_load)
#drop rows with any missing values 
spotify_charts.dropna(how='any')
# Out:
#                                        title  rank        date  \
# 0         Despacito (Featuring Daddy Yankee)     1  2017-03-01
# 1                                  El Amante     2  2017-03-01
# 2                 Reggaetón Lento (Bailemos)     3  2017-03-01
# 3                               Shape of You     4  2017-03-01
# 4                    Chantaje (feat. Maluma)     5  2017-03-01
# ...                                      ...   ...         ...
# 21794464                 Sao Em Lại Tắt Máy?   196  2021-10-31
# 21794465                     I Love You 3000   197  2021-10-31
# 21794466   Stuck with U (with Justin Bieber)   198  2021-10-31
# 21794467                                 2 5   199  2021-10-31
# 21794468                         Blank Space   200  2021-10-31
#
#                           artist  \
# 0                     Luis Fonsi
# 1                      Nicky Jam
# 2                           CNCO
# 3                     Ed Sheeran
# 4                        Shakira
# ...                          ...
# 21794464  Phạm Nguyên Ngọc, Vanh
# 21794465        Stephanie Poetri
# 21794466           Ariana Grande
# 21794467                     Táo
# 21794468            Taylor Swift
#
#                                                         url     region  \
# 0         https://open.spotify.com/track/4aWmUDTfIPGksMN...  Argentina
# 1         https://open.spotify.com/track/3umS4y3uQDkqekN...  Argentina
# 2         https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina
# 3         https://open.spotify.com/track/7qiZfU4dY1lWllz...  Argentina
# 4         https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina
# ...                                                     ...        ...
# 21794464  https://open.spotify.com/track/350jyz12XEeC1bl...    Vietnam
# 21794465  https://open.spotify.com/track/3znQ9i61vfe2E7U...    Vietnam
# 21794466  https://open.spotify.com/track/4HBZA5flZLE435Q...    Vietnam
# 21794467  https://open.spotify.com/track/3pvYWi5tsEn2pM9...    Vietnam
# 21794468  https://open.spotify.com/track/1u8c2t2Cy7UBoG4...    Vietnam
#
#            chart          trend   streams
# 0         top200  SAME_POSITION  365941.0
# 1         top200  SAME_POSITION  179697.0
# 2         top200  SAME_POSITION  169647.0
# 3         top200  SAME_POSITION  168495.0
# 4         top200  SAME_POSITION  141696.0
# ...          ...            ...       ...
# 21794464  top200      MOVE_DOWN    4526.0
# 21794465  top200      NEW_ENTRY    4525.0
# 21794466  top200      MOVE_DOWN    4461.0
# 21794467  top200      NEW_ENTRY    4443.0
# 21794468  top200      NEW_ENTRY    4434.0
#
# [19873403 rows x 9 columns]

# %% [markdown]
# # Importing SoundCloud song info data

# %%
# File to Load
file_to_load2 = "Data/Soundcloud_data.csv"

# Read Purchasing File and store into Pandas data frame
soundcloud_data = pd.read_csv(file_to_load2)
#drop rows with any missing values 
soundcloud_data.dropna(how='any')
# Out:
#                      track_id  \
# 0      004s3t0ONYlzxII9PLgU6z
# 1      00chLpzhgVjxs1zKC9UScL
# 2      00cqd6ZsSkLZqGMlQCR0Zo
# 3      00emjlCv9azBN0fzuuyLqy
# 4      00f9VGHfQhAHMCQ2bSjg3D
# ...                       ...
# 14982  6uS8KevqrhUjVjFZfWxsTh
# 14983  6uSa5iCMwPr10Ftpz8w09b
# 14984  6UsNqIqCC9WIDdg9Xxxv84
# 14985  6uSSupG4TMu3vW8QgynAB6
# 14986  6uThor8zg7TzTFNDj5q0mO
#
#                                               track_name  \
# 0                                           I Feel Alive
# 1                                                 Poison
# 2      Baby It's Cold Outside (feat. Christina Aguilera)
# 3                                             Dumb Litty
# 4                                                Soldier
# ...                                                  ...
# 14982                                          Limitless
# 14983                                               Love
# 14984                                      Trial By Fire
# 14985                 Startender (feat. Offset and Tyga)
# 14986                                High School Dropout
#
#                  track_artist  \
# 0               Steady Rollin
# 1              Bell Biv DeVoe
# 2                 CeeLo Green
# 3                        KARD
# 4                    James TW
# ...                       ...
# 14982                   Logic
# 14983         Musiq Soulchild
# 14984                    Saul
# 14985  A Boogie Wit da Hoodie
# 14986             Neon Dreams
#
#                                                   lyrics  track_popularity  \
# 0      The trees, are singing in the wind The sky blu...                28
# 1      NA Yeah, Spyderman and Freeze in full effect U...                 0
# 2      I really can't stay Baby it's cold outside I'v...                41
# 3      Get up out of my business You don't keep me fr...                65
# 4      Hold your breath, don't look down, keep trying...                70
# ...                                                  ...               ...
# 14982  You the man, you know you the man Rollie on yo...                 7
# 14983  Love So many things I've got to tell you But I...                54
# 14984  Walk in the coals, I'm seeing red I feel the h...                48
# 14985  Yeah, shawty got ass, she just got a tummy tuc...                66
# 14986  I was singing, I was singing those same damn b...                 2
#
#                track_album_id                      track_album_name  \
# 0      3z04Lb9Dsilqw68SHt6jLB                           Love & Loss
# 1      6oZ6brjB8x3GoeSYdwJdPc                                  Gold
# 2      3ssspRe42CXkhPxdc12xcp                  CeeLo's Magic Moment
# 3      7h5X3xhh3peIK9Y0qI5hbK  KARD 2nd Digital Single ‘Dumb Litty’
# 4      3GNzXsFbzdwM0WKCZtgeNP                              Chapters
# ...                       ...                                   ...
# 14982  6GeHCNwwqMMUrpxuGTRYcf       Confessions of a Dangerous Mind
# 14983  2RmMKj20xouC3Mqq1CyZ3c                        Aijuswanaseing
# 14984  3DPvNhIf6Tw98MhLcGlMWw                         Trial By Fire
# 14985  6qx6AMrns8Ruk1FinKg2qK    Startender (feat. Offset and Tyga)
# 14986  39kp5LRtnwf6ND9kFcjSZk                   High School Dropout
#
#       track_album_release_date  \
# 0                   11/21/2017
# 1                     1/1/2005
# 2                   10/29/2012
# 3                    9/22/2019
# 4                    4/26/2019
# ...                        ...
# 14982                5/10/2019
# 14983                 1/1/2000
# 14984               11/15/2019
# 14985               12/14/2018
# 14986                 1/4/2019
#
#                                            playlist_name  \
# 0                                      Hard Rock Workout
# 1      Back in the day - R&B, New Jack Swing, Swingbe...
# 2                                         Christmas Soul
# 3                                      K-Party Dance Mix
# 4                                     urban contemporary
# ...                                                  ...
# 14982                                      This Is Logic
# 14983                                Neo-Soul Essentials
# 14984                                          Rock Hard
# 14985                                     Trap Americana
# 14986                                    Electropop 2019
#
#                   playlist_id  ... mode speechiness  acousticness  \
# 0      3YouF0u7waJnolytf9JCXf  ...    1      0.0442      0.011700
# 1      3a9y4eeCJRmG9p4YKfqYIx  ...    0      0.2160      0.004320
# 2      6FZYc2BvF7tColxO8PBShV  ...    0      0.0341      0.689000
# 3      37i9dQZF1DX4RDXswvP6Mj  ...    1      0.0409      0.037000
# 4      4WiB26kw0INKwbzfb5M6Tv  ...    1      0.0550      0.280000
# ...                       ...  ...  ...         ...           ...
# 14982  37i9dQZF1DWTIuAboZgTMf  ...    1      0.0933      0.043500
# 14983  0DIwi1dMI59NItQtiNcevy  ...    0      0.0499      0.342000
# 14984  37i9dQZF1DWWJOmJ7nRx0C  ...    1      0.1450      0.000021
# 14985  7tkgK1tm9hYkWp7EFyOcAr  ...    0      0.1330      0.023500
# 14986  4Bi8VLtaSu0JILliif8lH6  ...    0      0.2900      0.043700
#
#        instrumentalness  liveness  valence    tempo  duration_ms  language  \
# 0              0.009940    0.3470    0.404  135.225       373512        en
# 1              0.007230    0.4890    0.650  111.904       262467        en
# 2              0.000000    0.0664    0.405  118.593       243067        en
# 3              0.000000    0.1380    0.240  130.018       193160        en
# 4              0.000000    0.0975    0.305  147.764       224720        en
# ...                 ...       ...      ...      ...          ...       ...
# 14982          0.000121    0.0924    0.715  155.059       244680        en
# 14983          0.000000    0.0876    0.339   99.739       304667        en
# 14984          0.493000    0.3050    0.572  192.118       211000        en
# 14985          0.000000    0.1510    0.506  191.971       192779        en
# 14986          0.000000    0.0702    0.882  112.041       184552        en
#
#                                                    links
# 0      http://soundcloud.com/xobak3r/purple-vision-ft...
# 1      http://soundcloud.com/user-704515444/bell-biv-...
# 2      http://soundcloud.com/atlanticrecords/cee-lo-g...
# 3      http://soundcloud.com/amber-lauwers-252961203/...
# 4             http://soundcloud.com/jamestwmusic/soldier
# ...                                                  ...
# 14982    http://soundcloud.com/boy-pablo777/sick-feeling
# 14983          http://soundcloud.com/navmusic/some-way-1
# 14984  http://soundcloud.com/spinninrecords/qulinez-r...
# 14985  http://soundcloud.com/gwop_wavy/ponderosa-twin...
# 14986  http://soundcloud.com/cleopatra-recs/father-mc...
#
# [14987 rows x 26 columns]

# %% [markdown]
# # The Cleaning and Manipulation of The Spotify Top 200 Chart csv
# In the cells below we:
#
#     - Filtered the data, keeping the chart information from only the years 2019-2021
#     - Narrowed down the region, only showing the top charts from The United States
#     - Got rid of any unneccessary information such as the "Viral50" information
#     - Narrowed it down to the top 50 songs at the first of every month from 2019-2021

# %%
#view your data
spotify_charts
# Out:
#                                        title  rank        date         artist  \
# 0         Despacito (Featuring Daddy Yankee)     1  2017-03-01     Luis Fonsi
# 1                                  El Amante     2  2017-03-01      Nicky Jam
# 2                 Reggaetón Lento (Bailemos)     3  2017-03-01           CNCO
# 3                               Shape of You     4  2017-03-01     Ed Sheeran
# 4                    Chantaje (feat. Maluma)     5  2017-03-01        Shakira
# ...                                      ...   ...         ...            ...
# 25512197                       Ký Ức Trốn Đi    46  2021-09-30            NHA
# 25512198               có hẹn với thanh xuân    47  2021-09-30        MONSTAR
# 25512199           Dive with you (feat. eaJ)    48  2021-09-30          Seori
# 25512200             Never Gonna Give You Up    49  2021-09-30    Rick Astley
# 25512201                        Reminiscence    50  2021-09-30  Jung Kyung Ho
#
#                                                         url     region  \
# 0         https://open.spotify.com/track/4aWmUDTfIPGksMN...  Argentina
# 1         https://open.spotify.com/track/3umS4y3uQDkqekN...  Argentina
# 2         https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina
# 3         https://open.spotify.com/track/7qiZfU4dY1lWllz...  Argentina
# 4         https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina
# ...                                                     ...        ...
# 25512197  https://open.spotify.com/track/2KslYHjvn4m1uZq...    Vietnam
# 25512198  https://open.spotify.com/track/54UNNgtE3zzERwT...    Vietnam
# 25512199  https://open.spotify.com/track/5RqwjQWDwxQ3HTk...    Vietnam
# 25512200  https://open.spotify.com/track/4cOdK2wGLETKBW3...    Vietnam
# 25512201  https://open.spotify.com/track/32noSNlGBJlVXPn...    Vietnam
#
#             chart          trend   streams
# 0          top200  SAME_POSITION  365941.0
# 1          top200  SAME_POSITION  179697.0
# 2          top200  SAME_POSITION  169647.0
# 3          top200  SAME_POSITION  168495.0
# 4          top200  SAME_POSITION  141696.0
# ...           ...            ...       ...
# 25512197  viral50        MOVE_UP       NaN
# 25512198  viral50      NEW_ENTRY       NaN
# 25512199  viral50      MOVE_DOWN       NaN
# 25512200  viral50      NEW_ENTRY       NaN
# 25512201  viral50      MOVE_DOWN       NaN
#
# [25512202 rows x 9 columns]

# %%
#narrow down date, only showing from January of 2019 to present
spotify_charts = spotify_charts.drop(labels=range(0, 5723700), axis=0)

# %%
#limit the region to the top songs in The United States
usa_chart= spotify_charts.loc[spotify_charts['region']=='United States']
USA = pd.DataFrame(usa_chart)

# %%
#get rid of "Viral50" lists because it is not relevant to our charts 
only_top_200= USA[USA["chart"].str.contains("viral50")==False]

# %%
only_top_200=pd.DataFrame(only_top_200)

# %%
#get rid of trend column because it does not add any useful data to our analysis 
del only_top_200['trend']

# %%
#drop any missing rows NAN
only_top_200.dropna()
# Out:
#                                                       title  rank        date  \
# 5723700       Sunflower - Spider-Man: Into the Spider-Verse     1  2019-01-01
# 5723701                                                Wow.     2  2019-01-01
# 5723702                                          SICKO MODE     3  2019-01-01
# 5723703                                       thank u, next     4  2019-01-01
# 5723704                             Going Bad (feat. Drake)     5  2019-01-01
# ...                                                     ...   ...         ...
# 21792722                                          The Hills   196  2021-10-31
# 21792723                 Black Magic Woman - Single Version   197  2021-10-31
# 21792724       Sad Girlz Luv Money Remix (feat. Kali Uchis)   198  2021-10-31
# 21792725                  Edge of Seventeen - 2016 Remaster   199  2021-10-31
# 21792726  Whats Poppin (feat. DaBaby, Tory Lanez & Lil W...   200  2021-10-31
#
#                          artist  \
# 5723700   Post Malone, Swae Lee
# 5723701             Post Malone
# 5723702            Travis Scott
# 5723703           Ariana Grande
# 5723704               Meek Mill
# ...                         ...
# 21792722             The Weeknd
# 21792723                Santana
# 21792724         Amaarae, Moliy
# 21792725           Stevie Nicks
# 21792726            Jack Harlow
#
#                                                         url         region  \
# 5723700   https://open.spotify.com/track/3KkXRkHbMCARz0a...  United States
# 5723701   https://open.spotify.com/track/6MWtB6iiXyIwun0...  United States
# 5723702   https://open.spotify.com/track/2xLMifQCjDGFmkH...  United States
# 5723703   https://open.spotify.com/track/2rPE9A1vEgShuZx...  United States
# 5723704   https://open.spotify.com/track/2IRZnDFmlqMuOrY...  United States
# ...                                                     ...            ...
# 21792722  https://open.spotify.com/track/7fBv7CLKzipRk6E...  United States
# 21792723  https://open.spotify.com/track/4YMQXzscifAREG0...  United States
# 21792724  https://open.spotify.com/track/15HMh4yxdf4wyxS...  United States
# 21792725  https://open.spotify.com/track/7L3b6iaVhDVjfo5...  United States
# 21792726  https://open.spotify.com/track/0ZLuW8uOXdFNWcI...  United States
#
#            chart    streams
# 5723700   top200  1867789.0
# 5723701   top200  1564946.0
# 5723702   top200  1454622.0
# 5723703   top200  1397512.0
# 5723704   top200  1245437.0
# ...          ...        ...
# 21792722  top200   204641.0
# 21792723  top200   204419.0
# 21792724  top200   204378.0
# 21792725  top200   203762.0
# 21792726  top200   203145.0
#
# [237000 rows x 8 columns]

# %%
#to better read our data, we are limiting it to the top 50 instead of the top 200
top_50_only = only_top_200.drop(only_top_200["rank"].loc[only_top_200["rank"] > 50].index)

# %%
top_50_only= pd.DataFrame(top_50_only)

# %%
#only keep the 1st of every month 
#this will allow us to see the top 50 of each month of the year
#still provides us with 1700 rows of data 
monthly= top_50_only.loc[(top_50_only['date'] == '2019-01-01') | 
                         (top_50_only['date'] == '2019-02-01')| 
                         (top_50_only['date'] == '2019-03-01')| 
                         (top_50_only['date'] == '2019-04-01')| 
                         (top_50_only['date'] == '2019-05-01')| 
                         (top_50_only['date'] == '2019-06-01')| 
                         (top_50_only['date'] == '2019-07-01')| 
                         (top_50_only['date'] == '2019-08-01')| 
                         (top_50_only['date'] == '2019-09-01')| 
                         (top_50_only['date'] == '2019-10-01')| 
                         (top_50_only['date'] == '2019-11-01')| 
                         (top_50_only['date'] == '2019-12-01')| 
                         (top_50_only['date'] == '2020-01-01')|
                         (top_50_only['date'] == '2020-02-01')|
                         (top_50_only['date'] == '2020-03-01')|
                         (top_50_only['date'] == '2020-04-01')|
                         (top_50_only['date'] == '2020-05-01')|
                         (top_50_only['date'] == '2020-06-01')|
                         (top_50_only['date'] == '2020-07-01')|
                         (top_50_only['date'] == '2020-08-01')|
                         (top_50_only['date'] == '2020-09-01')|
                         (top_50_only['date'] == '2020-10-01')|
                         (top_50_only['date'] == '2020-11-01')|
                         (top_50_only['date'] == '2020-12-01')|
                         (top_50_only['date'] == '2021-01-01')|
                         (top_50_only['date'] == '2021-02-01')|
                         (top_50_only['date'] == '2021-03-01')|
                         (top_50_only['date'] == '2021-04-01')|
                         (top_50_only['date'] == '2021-05-01')|
                         (top_50_only['date'] == '2021-06-01')|
                         (top_50_only['date'] == '2021-07-01')|
                         (top_50_only['date'] == '2021-08-01')|
                         (top_50_only['date'] == '2021-09-01')|
                         (top_50_only['date'] == '2021-10-01')]

# %%
monthly
# Out:
#                                                       title  rank        date  \
# 5723700       Sunflower - Spider-Man: Into the Spider-Verse     1  2019-01-01
# 5723701                                                Wow.     2  2019-01-01
# 5723702                                          SICKO MODE     3  2019-01-01
# 5723703                                       thank u, next     4  2019-01-01
# 5723704                             Going Bad (feat. Drake)     5  2019-01-01
# ...                                                     ...   ...         ...
# 17573419  ...And to Those I Love, Thanks for Sticking Ar...    46  2021-10-01
# 17573420                                     No Role Modelz    47  2021-10-01
# 17573421                            Cold Heart - PNAU Remix    48  2021-10-01
# 17573422                                             Freaks    49  2021-10-01
# 17573423                  Wildest Dreams (Taylor's Version)    50  2021-10-01
#
#                          artist  \
# 5723700   Post Malone, Swae Lee
# 5723701             Post Malone
# 5723702            Travis Scott
# 5723703           Ariana Grande
# 5723704               Meek Mill
# ...                         ...
# 17573419            $uicideboy$
# 17573420                J. Cole
# 17573421   Elton John, Dua Lipa
# 17573422             Surf Curse
# 17573423           Taylor Swift
#
#                                                         url         region  \
# 5723700   https://open.spotify.com/track/3KkXRkHbMCARz0a...  United States
# 5723701   https://open.spotify.com/track/6MWtB6iiXyIwun0...  United States
# 5723702   https://open.spotify.com/track/2xLMifQCjDGFmkH...  United States
# 5723703   https://open.spotify.com/track/2rPE9A1vEgShuZx...  United States
# 5723704   https://open.spotify.com/track/2IRZnDFmlqMuOrY...  United States
# ...                                                     ...            ...
# 17573419  https://open.spotify.com/track/30QR0ndUdiiMQMA...  United States
# 17573420  https://open.spotify.com/track/62vpWI1CHwFy7tM...  United States
# 17573421  https://open.spotify.com/track/6zSpb8dQRaw0M1d...  United States
# 17573422  https://open.spotify.com/track/7EkWXAI1wn8Ii88...  United States
# 17573423  https://open.spotify.com/track/1Ov37jtRQ2YNAe8...  United States
#
#            chart    streams
# 5723700   top200  1867789.0
# 5723701   top200  1564946.0
# 5723702   top200  1454622.0
# 5723703   top200  1397512.0
# 5723704   top200  1245437.0
# ...          ...        ...
# 17573419  top200   423243.0
# 17573420  top200   422162.0
# 17573421  top200   421097.0
# 17573422  top200   418368.0
# 17573423  top200   414966.0
#
# [1700 rows x 8 columns]

# %%
first_of_month_df= pd.DataFrame(monthly)

# %%
#drop chart column bc it is no longer relevant (we are only looking at the top 50)
del first_of_month_df['chart']

# %%
first_of_month_df
# Out:
#                                                       title  rank        date  \
# 5723700       Sunflower - Spider-Man: Into the Spider-Verse     1  2019-01-01
# 5723701                                                Wow.     2  2019-01-01
# 5723702                                          SICKO MODE     3  2019-01-01
# 5723703                                       thank u, next     4  2019-01-01
# 5723704                             Going Bad (feat. Drake)     5  2019-01-01
# ...                                                     ...   ...         ...
# 17573419  ...And to Those I Love, Thanks for Sticking Ar...    46  2021-10-01
# 17573420                                     No Role Modelz    47  2021-10-01
# 17573421                            Cold Heart - PNAU Remix    48  2021-10-01
# 17573422                                             Freaks    49  2021-10-01
# 17573423                  Wildest Dreams (Taylor's Version)    50  2021-10-01
#
#                          artist  \
# 5723700   Post Malone, Swae Lee
# 5723701             Post Malone
# 5723702            Travis Scott
# 5723703           Ariana Grande
# 5723704               Meek Mill
# ...                         ...
# 17573419            $uicideboy$
# 17573420                J. Cole
# 17573421   Elton John, Dua Lipa
# 17573422             Surf Curse
# 17573423           Taylor Swift
#
#                                                         url         region  \
# 5723700   https://open.spotify.com/track/3KkXRkHbMCARz0a...  United States
# 5723701   https://open.spotify.com/track/6MWtB6iiXyIwun0...  United States
# 5723702   https://open.spotify.com/track/2xLMifQCjDGFmkH...  United States
# 5723703   https://open.spotify.com/track/2rPE9A1vEgShuZx...  United States
# 5723704   https://open.spotify.com/track/2IRZnDFmlqMuOrY...  United States
# ...                                                     ...            ...
# 17573419  https://open.spotify.com/track/30QR0ndUdiiMQMA...  United States
# 17573420  https://open.spotify.com/track/62vpWI1CHwFy7tM...  United States
# 17573421  https://open.spotify.com/track/6zSpb8dQRaw0M1d...  United States
# 17573422  https://open.spotify.com/track/7EkWXAI1wn8Ii88...  United States
# 17573423  https://open.spotify.com/track/1Ov37jtRQ2YNAe8...  United States
#
#             streams
# 5723700   1867789.0
# 5723701   1564946.0
# 5723702   1454622.0
# 5723703   1397512.0
# 5723704   1245437.0
# ...             ...
# 17573419   423243.0
# 17573420   422162.0
# 17573421   421097.0
# 17573422   418368.0
# 17573423   414966.0
#
# [1700 rows x 7 columns]

# %%
first_of_month_df.to_csv('Data/cleaned_spotify_data.csv', index = False)

# %% [markdown]
# # The Cleaning and Manipulation of the csv containing SoundCloud information, as well as other various musical components

# %%
#soundcloud_data
del soundcloud_data['track_id']
del soundcloud_data['track_artist']
del soundcloud_data['lyrics']
del soundcloud_data['track_album_id']
del soundcloud_data['playlist_name']
del soundcloud_data['playlist_id']
del soundcloud_data['language']

# %%
soundcloud_data
# Out:
#                                               track_name  track_popularity  \
# 0                                           I Feel Alive                28
# 1                                                 Poison                 0
# 2      Baby It's Cold Outside (feat. Christina Aguilera)                41
# 3                                             Dumb Litty                65
# 4                                                Soldier                70
# ...                                                  ...               ...
# 17105                                           Some Way                72
# 17106                    Rising Like The Sun - Radio Mix                 0
# 17107                                           Anaconda                49
# 17108                                              Bound                40
# 17109             I'll Do 4 U (Re-Recorded / Remastered)                36
#
#                              track_album_name track_album_release_date  \
# 0                                 Love & Loss               11/21/2017
# 1                                        Gold                 1/1/2005
# 2                        CeeLo's Magic Moment               10/29/2012
# 3        KARD 2nd Digital Single ‘Dumb Litty’                9/22/2019
# 4                                    Chapters                4/26/2019
# ...                                       ...                      ...
# 17105                                     NAV                2/24/2017
# 17106                     Rising Like The Sun                3/24/2014
# 17107          The Pinkprint (Deluxe Edition)               12/15/2014
# 17108          2+2+1 = (Digitally Remastered)                 7/9/2013
# 17109  I'll Do 4 U (Re-Recorded / Remastered)                10/1/2010
#
#       playlist_genre          playlist_subgenre  danceability  energy  key  \
# 0               rock                  hard rock         0.303   0.880    9
# 1                r&b             new jack swing         0.845   0.652    6
# 2                r&b                   neo soul         0.425   0.378    5
# 3                pop                  dance pop         0.760   0.887    9
# 4                r&b         urban contemporary         0.496   0.639    6
# ...              ...                        ...           ...     ...  ...
# 17105            r&b         urban contemporary         0.744   0.715    0
# 17106            edm  progressive electro house         0.479   0.800   10
# 17107            pop                 electropop         0.963   0.603    2
# 17108            r&b                   neo soul         0.458   0.540    5
# 17109            r&b             new jack swing         0.832   0.666    1
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0        -4.739     1       0.0442       0.01170          0.009940    0.3470
# 1        -7.504     0       0.2160       0.00432          0.007230    0.4890
# 2        -5.819     0       0.0341       0.68900          0.000000    0.0664
# 3        -1.993     1       0.0409       0.03700          0.000000    0.1380
# 4        -6.157     1       0.0550       0.28000          0.000000    0.0975
# ...         ...   ...          ...           ...               ...       ...
# 17105    -6.103     1       0.3510       0.10100          0.000000    0.0919
# 17106    -5.778     0       0.0878       0.00555          0.000000    0.3350
# 17107    -6.224     1       0.1800       0.06730          0.000006    0.2140
# 17108    -6.457     0       0.0270       0.71500          0.000428    0.1150
# 17109    -4.920     0       0.0633       0.14300          0.000000    0.0720
#
#        valence    tempo  duration_ms  \
# 0        0.404  135.225       373512
# 1        0.650  111.904       262467
# 2        0.405  118.593       243067
# 3        0.240  130.018       193160
# 4        0.305  147.764       224720
# ...        ...      ...          ...
# 17105    0.340  154.962       179773
# 17106    0.211  128.012       208656
# 17107    0.647  129.990       260240
# 17108    0.657  142.218       191205
# 17109    0.810  109.536       223890
#
#                                                    links
# 0      http://soundcloud.com/xobak3r/purple-vision-ft...
# 1      http://soundcloud.com/user-704515444/bell-biv-...
# 2      http://soundcloud.com/atlanticrecords/cee-lo-g...
# 3      http://soundcloud.com/amber-lauwers-252961203/...
# 4             http://soundcloud.com/jamestwmusic/soldier
# ...                                                  ...
# 17105                                                NaN
# 17106                                                NaN
# 17107                                                NaN
# 17108                                                NaN
# 17109                                                NaN
#
# [17110 rows x 19 columns]

# %%
soundcloud_data.rename(columns={'track_name': 'title'}, inplace=True)

# %%
#merge first_of_month_df and soundcloud data on title 
merged_frames= first_of_month_df.merge(soundcloud_data, on='title', how='left')

# %%
#like why does it have #1 3 separate times for 2019-01-01 
clean_merge = merged_frames.drop_duplicates('title')
clean_merge = clean_merge.dropna()

# %%
clean_merge.reset_index(drop=True)
# Out:
#                                              title  rank        date  \
# 0    Sunflower - Spider-Man: Into the Spider-Verse     1  2019-01-01
# 1                                             Wow.     2  2019-01-01
# 2                                       SICKO MODE     3  2019-01-01
# 3                                    thank u, next     4  2019-01-01
# 4                          Going Bad (feat. Drake)     5  2019-01-01
# ..                                             ...   ...         ...
# 225                                          Woman    30  2021-09-01
# 226                                       Dark Red    44  2021-09-01
# 227                                    My Universe    29  2021-10-01
# 228                                   Life Goes On    37  2021-10-01
# 229                                 No Role Modelz    47  2021-10-01
#
#                     artist                                                url  \
# 0    Post Malone, Swae Lee  https://open.spotify.com/track/3KkXRkHbMCARz0a...
# 1              Post Malone  https://open.spotify.com/track/6MWtB6iiXyIwun0...
# 2             Travis Scott  https://open.spotify.com/track/2xLMifQCjDGFmkH...
# 3            Ariana Grande  https://open.spotify.com/track/2rPE9A1vEgShuZx...
# 4                Meek Mill  https://open.spotify.com/track/2IRZnDFmlqMuOrY...
# ..                     ...                                                ...
# 225               Doja Cat  https://open.spotify.com/track/6Uj1ctrBOjOas8x...
# 226             Steve Lacy  https://open.spotify.com/track/37y7iDayfwm3WXn...
# 227          Coldplay, BTS  https://open.spotify.com/track/3FeVmId7tL5YN8B...
# 228            Oliver Tree  https://open.spotify.com/track/0eu4C55hL6x29mm...
# 229                J. Cole  https://open.spotify.com/track/62vpWI1CHwFy7tM...
#
#             region    streams  track_popularity          track_album_name  \
# 0    United States  1867789.0              87.0      Hollywood's Bleeding
# 1    United States  1564946.0              41.0      Hollywood's Bleeding
# 2    United States  1454622.0              87.0                ASTROWORLD
# 3    United States  1397512.0              28.0             thank u, next
# 4    United States  1245437.0              85.0             Championships
# ..             ...        ...               ...                       ...
# 225  United States   677081.0              58.0                       Man
# 226  United States   517436.0              47.0         Steve Lacy's Demo
# 227  United States   560549.0              32.0  Masters Of The Dark Arts
# 228  United States   469780.0              60.0            All Eyez On Me
# 229  United States   422162.0              82.0   2014 Forest Hills Drive
#
#     track_album_release_date  ... loudness mode  speechiness  acousticness  \
# 0                   9/6/2019  ...   -4.368  1.0       0.0575       0.53300
# 1                   9/6/2019  ...   -7.359  0.0       0.2080       0.13600
# 2                   8/3/2018  ...   -3.714  1.0       0.2220       0.00513
# 3                  11/3/2018  ...   -5.642  1.0       0.0658       0.28000
# 4                 11/30/2018  ...   -6.365  0.0       0.0905       0.25900
# ..                       ...  ...      ...  ...          ...           ...
# 225                 1/1/1996  ...   -8.888  0.0       0.0261       0.09010
# 226                2/24/2017  ...   -4.023  1.0       0.0620       0.44900
# 227                7/31/2012  ...   -4.979  0.0       0.3920       0.05530
# 228                2/13/1996  ...   -5.463  1.0       0.2530       0.11700
# 229                12/9/2014  ...   -8.465  0.0       0.3320       0.30200
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 0            0.000000    0.0685    0.925   89.960     157560.0
# 1            0.000002    0.1030    0.388   99.960     149547.0
# 2            0.000000    0.1240    0.446  155.008     312820.0
# 3            0.000000    0.1020    0.435  106.960     207333.0
# 4            0.000000    0.2520    0.544   86.003     180522.0
# ..                ...       ...      ...      ...          ...
# 225          0.034600    0.1980    0.330  136.022     270400.0
# 226          0.000008    0.1190    0.775  172.041     173104.0
# 227          0.026300    0.3630    0.225   84.133     240733.0
# 228          0.000000    0.3430    0.529  158.465     301600.0
# 229          0.000000    0.0565    0.458  100.000     292987.0
#
#                                                  links
# 0    http://soundcloud.com/kyrnprod/cece-peniston-k...
# 1    http://soundcloud.com/kyralxbankovip/kaytranad...
# 2    http://soundcloud.com/eddies-christmas-songs/s...
# 3        http://soundcloud.com/keshibeats/right-here-1
# 4    http://soundcloud.com/dangelomusicofficial/shi...
# ..                                                 ...
# 225  http://soundcloud.com/gaga-digi/the-black-keys...
# 226  http://soundcloud.com/user-722796609/bass-boos...
# 227  http://soundcloud.com/mindrave/dj-khaled-wish-...
# 228  http://soundcloud.com/cleopatra-recs/freestyle...
# 229  http://soundcloud.com/thedoors/break-on-throug...
#
# [230 rows x 25 columns]

# %%
clean_merge.to_csv('Data/merged_data_frames.csv', index = False)

# %% [markdown]
# # Loading dataframe to MongoDB

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
data = clean_merge.to_dict(orient='records')

try: 
    db = client['spotify_db_msquared']
    collection = db['spotify_collection']
    collection.insert_many(data)
    print('the eagle has landed')

except: 
    print('the eagle is still flying')
# Out:
# the eagle has landed
